# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.4.0-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.37.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.4.0

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("all-MiniLM-L6-v2")

# Two lists of sentences
sentences1 = [
    "The cat sits outside",
    "A man is playing guitar",
    "The new movie is awesome",
]

sentences2 = [
    "The dog plays in the garden",
    "A woman watches TV",
    "The new movie is so great",
]

# Compute embedding for both lists
embeddings1 = model.encode(sentences1, convert_to_tensor=True)
embeddings2 = model.encode(sentences2, convert_to_tensor=True)

# Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings1, embeddings2)

# Output the pairs with their score
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f}".format(
        sentences1[i], sentences2[i], cosine_scores[i][i]
    ))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# The cat sits outside 		 The dog plays in the garden 		 Score: 0.2838
# A man is playing guitar 		 A woman watches TV 		 Score: -0.0327
# The new movie is awesome 		 The new movie is so great 		 Score: 0.8939

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
import pandas as pd

df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d5e8c50c4b30> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024')
#       4 df
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1523         content_or_path = BytesIO(content_or_path)
#    1524
# -> 1525     with get_handle(
#    1526         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024'

# %%
# code to create json from column PAparagraphs and save into column PApragraphs_Json

import pandas as pd
import json
import re
from openpyxl import load_workbook


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


def extract_and_convert(row):
    #data = re.findall(r'\[([^]]+)\]\n([^[]+)', row)
    data = re.findall(r'\[([^]]+)\](?:\n)?\s*([^[]+)', row)
    return {
        "sentences": [{"id": d[0], "content": d[1].strip()} for d in data]
    }


df['PApragraphs_Json'] = df['PAparagraphs'].apply(extract_and_convert)


df['PApragraphs_Json'] = df['PApragraphs_Json'].apply(lambda x: json.dumps(x, ensure_ascii=False))


#with pd.ExcelWriter('gdrive/MyDrive/ClaimCiteRetrieval_ESR_based_new.xlsx', engine='openpyxl') as writer:
#    df.to_excel(writer, sheet_name='Sheet1', index=False)
df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)

# %%
#code to try sentence embedding(not in use)

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import json


model = SentenceTransformer("all-MiniLM-L6-v2")


df = pd.read_excel('gdrive/MyDrive/ClaimCiteRetrieval_ESR_based_new.xlsx')


for index, row in df.iterrows():
    col1_text = row['APclaim']


    col2_json = json.loads(row['PApragraphs_Json'])


    sentences1 = [col1_text]
    for item in col2_json['sentences']:
        sentences2_id = [item['id']]
        sentences2_content = [item['content']]
        # Print or use the results as needed
        #print(f"sentences1 = {sentences1}")
        #print(f"sentences2 = {sentences2}")
        #print()

        embeddings1 = model.encode(sentences1, convert_to_tensor=True)
        embeddings2 = model.encode(sentences2_content, convert_to_tensor=True)
        cosine_scores = util.cos_sim(embeddings1, embeddings2)


        for i in range(len(sentences1)):
            print("{} \n\n {} \n\n {} \n\n Score: {:.4f}".format(
                sentences1[i],sentences2_id[i], sentences2_content[i], cosine_scores[i][i]
            ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c4b4bbb2bf3f> in <cell line: 13>()
#      43         })
#      44         # Convert the list of dictionaries to a JSON string
# ---> 45         output_json_str = json.dumps({"sentences": output_json}, indent=2)
#      46
#      47         # Save the JSON string in a new column in the DataFrame
#
# /usr/lib/python3.10/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.10/json/encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# --> 201             chunks = list(chunks)
#     202         return ''.join(chunks)
#     203
#
# /usr/lib/python3.10/json/encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# /usr/lib/python3.10/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# /usr/lib/python3.10/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# /usr/lib/python3.10/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# /usr/lib/python3.10/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# /usr/lib/python3.10/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type Tensor is not JSON serializable

# %%
#Task 1,case 1.1 (step 1 to json)

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import json

model = SentenceTransformer("all-mpnet-base-v2")


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


for index, row in df.iterrows():
    col1_text = row['APclaim']


    col2_text = row['PAclaim']


    sentences1 = [col1_text]
    sentences2 = [col2_text]

    output_json = []



    embeddings1 = model.encode(sentences1, convert_to_tensor=True)
    embeddings2 = model.encode(sentences2, convert_to_tensor=True)
    cosine_scores = util.cos_sim(embeddings1, embeddings2).item()  # Convert the tensor to a float

    output_json.append({
        "sentences1": sentences1,
        "sentences2": sentences2,
        "score": "{:.4f}".format(cosine_scores)
    })


    output_json_str = json.dumps({"sentences": output_json}, indent=2)


    df.at[index, 'APclaimPAclaim-sim-mpnet-json'] = output_json_str


df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#Task 1,case 1.1 (step 2) - find score in APclaimPAclaim-sim-mpnet-json column and save it in APclaimPAclaim-sim-mpnet
import pandas as pd
import json


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


def extract_score(row):
    try:
        json_data = json.loads(row['APclaimPAclaim-sim-mpnet-json'])
        score = json_data['sentences'][0]['score']
        return float(score)
    except (json.JSONDecodeError, KeyError, IndexError):
        return None


df['APclaimPAclaim-sim-mpnet'] = df.apply(extract_score, axis=1)


df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)

# %%
#Task 1 part 1.1
import pandas as pd
df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')
min_value = df['APclaimPAclaim-sim-mpnet'].min()
max_value = df['APclaimPAclaim-sim-mpnet'].max()
avg_value = df['APclaimPAclaim-sim-mpnet'].mean()
print("Minimum value_APclaimPAclaim-sim-mpnet:", min_value)
print("Maximum value_APclaimPAclaim-sim-mpnet:", max_value)
print("Average value_APclaimPAclaim-sim-mpnet:", avg_value)
# Out:
# Minimum value_APclaimPAclaim-sim-mpnet: 0.2795
# Maximum value_APclaimPAclaim-sim-mpnet: 0.9851
# Average value_APclaimPAclaim-sim-mpnet: 0.6248040816326531

# %%
#Task 1,case 1.2 (step 1)

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import json

model = SentenceTransformer("all-mpnet-base-v2")


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


for index, row in df.iterrows():
    col1_text = row['APclaim']


    col2_text = row['PAabstract']


    sentences1 = [col1_text]
    sentences2 = [col2_text]

    output_json = []



    embeddings1 = model.encode(sentences1, convert_to_tensor=True)
    embeddings2 = model.encode(sentences2, convert_to_tensor=True)
    cosine_scores = util.cos_sim(embeddings1, embeddings2).item()  # Convert the tensor to a float

    output_json.append({
        "sentences1": sentences1,
        "sentences2": sentences2,
        "score": "{:.4f}".format(cosine_scores)
    })


    output_json_str = json.dumps({"sentences": output_json}, indent=2)


    df.at[index, 'APclaimPAabstract-sim-mpnet-json'] = output_json_str


df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)

# %%
#Task 1,case 1.2 (step 2)
import pandas as pd
import json


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


def extract_score(row):
    try:
        json_data = json.loads(row['APclaimPAabstract-sim-mpnet-json'])
        score = json_data['sentences'][0]['score']
        return float(score)
    except (json.JSONDecodeError, KeyError, IndexError):
        return None


df['APclaimPAabstract-sim-mpnet'] = df.apply(extract_score, axis=1)


df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)

# %%
#Task 1 part 1.2
import pandas as pd
df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')
min_value = df['APclaimPAabstract-sim-mpnet'].min()
max_value = df['APclaimPAabstract-sim-mpnet'].max()
avg_value = df['APclaimPAabstract-sim-mpnet'].mean()
print("Minimum value_APclaimPAabstract-sim-mpnet:", min_value)
print("Maximum value_APclaimPAabstract-sim-mpnet:", max_value)
print("Average value_APclaimPAabstract-sim-mpnet:", avg_value)
# Out:
# Minimum value_APclaimPAabstract-sim-mpnet: 0.3129
# Maximum value_APclaimPAabstract-sim-mpnet: 0.8993
# Average value_APclaimPAabstract-sim-mpnet: 0.5956204081632653

# %%
#code for sentence embedding (Task 2) saving new json with score in a new column PAparagraphs_sim-mpnet

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import json

model = SentenceTransformer("all-mpnet-base-v2")


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


for index, row in df.iterrows():
    col1_text = row['APclaim']


    col2_json = json.loads(row['PApragraphs_Json'])


    sentences1 = [col1_text]

    output_json = []
    for item in col2_json['sentences']:
        sentences2_id = item['id']
        sentences2_content = item['content']

        embeddings1 = model.encode(sentences1, convert_to_tensor=True)
        embeddings2 = model.encode(sentences2_content, convert_to_tensor=True)
        cosine_scores = util.cos_sim(embeddings1, embeddings2).item()  # Convert the tensor to a float

        output_json.append({
            "id": sentences2_id,
            "content": sentences2_content,
            "score": "{:.4f}".format(cosine_scores)
        })


    output_json_str = json.dumps({"sentences": output_json}, indent=2)


    df.at[index, 'PAparagraphs_sim-mpnet'] = output_json_str


df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#code to calculate top 3 scores (task 3) and save in new column PAparagraphs-sim-mpnet-top123
import pandas as pd
import json


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


def get_top_3(row):
    try:
        output_json = json.loads(row['PAparagraphs_sim-mpnet'])
        sorted_scores = sorted(output_json['sentences'], key=lambda x: float(x['score']), reverse=True)
        top_3 = [[item['id'], "{:.4f}".format(float(item['score']))] for item in sorted_scores[:3]]
        return top_3
    except (json.JSONDecodeError, KeyError):
        return []


df['PAparagraphs-sim-mpnet-top123'] = df.apply(get_top_3, axis=1)
df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)

# %%
#Task 4, 4.1(1)
import pandas as pd
import ast

df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')


df['PAparagraphs-sim-mpnet-top123']  = df['PAparagraphs-sim-mpnet-top123'].apply(ast.literal_eval)

first_values = [item[0] for sublist in df['PAparagraphs-sim-mpnet-top123'] for item in sublist]

grouped_values = [f"[{value}]" for value in first_values]

other_column_values = df['PAcited'].tolist()

results_list = []
count_true_1 = count_true_2 = count_true_3 = 0


for i in range(0, len(grouped_values), 3):
    row_values = grouped_values[i:i+3]
    other_values = other_column_values[i//3]

    results = [str(value in other_values) for value in row_values]
    count_true_1 += int(results[0] == 'True')
    count_true_2 += int(results[1] == 'True')
    count_true_3 += int(results[2] == 'True')

    results_list.append(results)


    print("Values from 'top123':", row_values)
    print("Values from 'other_column':", other_values)
    print("Result:", ",".join(results))
    print()

total_rows = len(results_list)
av1 = (count_true_1 / total_rows) * 100
av2 = (count_true_2 / total_rows) * 100
av3 = (count_true_3 / total_rows) * 100

average_of_averages = (av1 + av2 + av3) / 3


print("Top1_mpnet_accuracy:", av1)
print("Top2_mpnet_accuracy:", av2)
print("Top3_mpnet_accuracy:", av3)

print("Average of av1, av2, av3:", average_of_averages)
# Out:
# Values from 'top123': ['[0058]', '[0060]', '[0059]']
# Values from 'other_column': [0060],[0061],[0092]
# Result: False,True,False
#
# Values from 'top123': ['[0015]', '[0010]', '[0005]']
# Values from 'other_column': [0005],[0009],[0015]
# Result: True,False,True
#
# Values from 'top123': ['[0006]', '[0004]', '[0039]']
# Values from 'other_column': [0002],[0006],[0027]
# Result: True,False,False
#
# Values from 'top123': ['[0007]', '[0009]', '[0004]']
# Values from 'other_column': [0005],[0007],[0019]
# Result: True,False,False
#
# Values from 'top123': ['[0039]', '[0037]', '[0027]']
# Values from 'other_column': [0024],[0025],[0037]
# Result: False,True,False
#
# Values from 'top123': ['[0288]', '[0287]', '[0224]']
# Values from 'other_column': [0228],[0224],[0290]
# Result: False,False,True
#
# Values from 'top123': ['[0026]', '[0007]', '[0027]']
# Values from 'other_column': [0006],[0029],[0002]
# Result: False,False,False
#
# Values from 'top123': ['[0041]', '[0010]', '[0023]']
# Values from 'other_column': [0008],[0023],[0041]
# Result: True,False,True
#
# Values from 'top123': ['[0061]', '[0031]', '[0030]']
# Values from 'other_column': [0031],[0034],[0061]
# Result: True,True,False
#
# Values from 'top123': ['[0008]', '[0007]', '[0006]']
# Values from 'other_column': [0002],[0006],[0030]
# Result: False,False,True
#
# Values from 'top123': ['[0012]', '[0011]', '[0010]']
# Values from 'other_column': [0012],[0037],[0056]
# Result: True,False,False
#
# Values from 'top123': ['[0003]', '[0024]', '[0023]']
# Values from 'other_column': [0003],[0018],[0025]
# Result: True,False,False
#
# Values from 'top123': ['[0005]', '[0004]', '[0003]']
# Values from 'other_column': [0003],[0017],[0018]
# Result: False,False,True
#
# Values from 'top123': ['[0006]', '[0005]', '[0023]']
# Values from 'other_column': [0005],[0018],[0023]
# Result: False,True,True
#
# Values from 'top123': ['[0048]', '[0047]', '[0043]']
# Values from 'other_column': [0042],[0043],[0046]
# Result: False,False,True
#
# Values from 'top123': ['[0001]', '[0005]', '[0003]']
# Values from 'other_column': [0001],[0045],[0009]
# Result: True,False,False
#
# Values from 'top123': ['[0144]', '[0168]', '[0184]']
# Values from 'other_column': [0144],[0172],[0182]
# Result: True,False,False
#
# Values from 'top123': ['[0028]', '[0012]', '[0008]']
# Values from 'other_column': [0010],[0012],[0028]
# Result: True,True,False
#
# Values from 'top123': ['[0024]', '[0058]', '[0011]']
# Values from 'other_column': [0011],[0024],[0054]
# Result: True,False,True
#
# Values from 'top123': ['[0016]', '[66]', '[0015]']
# Values from 'other_column': [0016],[0055],[0066]
# Result: True,False,False
#
# Values from 'top123': ['[0008]', '[0009]', '[0012]']
# Values from 'other_column': [0009],[0012],[0075]
# Result: False,True,True
#
# Values from 'top123': ['[0018]', '[0009]', '[0030]']
# Values from 'other_column': [0001],[0009],[0030]
# Result: False,True,True
#
# Values from 'top123': ['[0016]', '[0014]', '[0019]']
# Values from 'other_column': [0014],[0017],[0020]
# Result: False,True,False
#
# Values from 'top123': ['[0055]', '[0027]', '[0056]']
# Values from 'other_column': [0027],[0028],[0053]
# Result: False,True,False
#
# Values from 'top123': ['[0013]', '[0012]', '[0006]']
# Values from 'other_column': [0005],[0012],[0013]
# Result: True,True,False
#
# Values from 'top123': ['[0003]', '[0004]', '[0007]']
# Values from 'other_column': [0058], [0169], [0001]
# Result: False,False,False
#
# Values from 'top123': ['[0559]', '[0003]', '[0005]']
# Values from 'other_column': [0316],[0677],[0559]
# Result: True,False,False
#
# Values from 'top123': ['[0069]', '[0075]', '[0073]']
# Values from 'other_column': [0068],[0069],[0072]
# Result: True,False,False
#
# Values from 'top123': ['[0058]', '[0081]', '[0082]']
# Values from 'other_column': [0058],[0072],[0138]
# Result: True,False,False
#
# Values from 'top123': ['[0001]', '[0005]', '[0003 ]']
# Values from 'other_column': [0014],[0018],[0013]
# Result: False,False,False
#
# Values from 'top123': ['[0006]', '[0003]', '[0039]']
# Values from 'other_column': [0023],[0038],[0039]
# Result: False,False,True
#
# Values from 'top123': ['[0003]', '[0002]', '[0028]']
# Values from 'other_column': [0018],[0028],[0024]
# Result: False,False,True
#
# Values from 'top123': ['[0003]', '[0002]', '[0010]']
# Values from 'other_column': [0002],[0003],[0004]
# Result: True,True,False
#
# Values from 'top123': ['[0001]', '[0002]', '[0007]']
# Values from 'other_column': [0001],[0002],[0003]
# Result: True,True,False
#
# Values from 'top123': ['[0006]', '[0176]', '[0169]']
# Values from 'other_column': [0169],[0176],[0177]
# Result: False,True,True
#
# Values from 'top123': ['[0002]', '[0014]', '[0003]']
# Values from 'other_column': [0014],[0021],[0027]
# Result: False,True,False
#
# Values from 'top123': ['[0004]', '[0007]', '[0003]']
# Values from 'other_column': [0006],[0025],[0045]
# Result: False,False,False
#
# Values from 'top123': ['[0009]', '[0003]', '[0023]']
# Values from 'other_column': [0009],[0023],[0165]
# Result: True,False,True
#
# Values from 'top123': ['[0014]', '[0004]', '[0001]']
# Values from 'other_column': [0011],[0014],[0020]
# Result: True,False,False
#
# Values from 'top123': ['[0005]', '[0009]', '[0001]']
# Values from 'other_column': [0002],[0009],[0020]
# Result: False,True,False
#
# Values from 'top123': ['[0004]', '[0001]', '[0002]']
# Values from 'other_column': [0002],[0004],[0014]
# Result: True,False,True
#
# Values from 'top123': ['[0004]', '[0005]', '[0042]']
# Values from 'other_column': [0004],[0127],[0042]
# Result: True,False,True
#
# Values from 'top123': ['[0001]', '[0003]', '[0044]']
# Values from 'other_column': [0004],[0044],[0077]
# Result: False,False,True
#
# Values from 'top123': ['[0046]', '[0044]', '[0003]']
# Values from 'other_column': [0020],[0021],[0043]
# Result: False,False,False
#
# Values from 'top123': ['[0009]', '[0008]', '[0004]']
# Values from 'other_column': [0003],[0006],[0008]
# Result: False,True,False
#
# Values from 'top123': ['[0169]', '[0162]', '[0005]']
# Values from 'other_column': [0108],[0162],[0169]
# Result: True,True,False
#
# Values from 'top123': ['[0006]', '[0004]', '[0005]']
# Values from 'other_column': [0002],[0006],[0008]
# Result: True,False,False
#
# Values from 'top123': ['[0005]', '[0032]', '[0007]']
# Values from 'other_column': [0004],[0005],[0032]
# Result: True,True,False
#
# Values from 'top123': ['[0002]', '[0096]', '[0004]']
# Values from 'other_column': [0002],[0096],[0117]
# Result: True,True,False
#
# Top1_mpnet_accuracy: 53.06122448979592
# Top2_mpnet_accuracy: 38.775510204081634
# Top3_mpnet_accuracy: 34.69387755102041
# Average of av1, av2, av3: 42.17687074829932

# %%
#Task 5 part 1.1 (To check)
import pandas as pd


df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')

df['PAparagraphs-sim-mpnet-top123'] = df['PAparagraphs-sim-mpnet-top123'].apply(ast.literal_eval)


for index, row in df.iterrows():
    top123_values = row['PAparagraphs-sim-mpnet-top123']
    print(f"Row {index + 1}: {top123_values}")

    last_three_values = [float(item[1]) for item in row['PAparagraphs-sim-mpnet-top123'][-3:]]
    average_last_three = sum(last_three_values) / len(last_three_values)

    print(f"Row {index + 1}: Average of last three values: {average_last_three}")
    print()
# Out:
# Row 1: [['0058', '0.5168'], ['0060', '0.5138'], ['0059', '0.5051']]
# Row 1: Average of last three values: 0.5119000000000001
#
# Row 2: [['0015', '0.6420'], ['0010', '0.5999'], ['0005', '0.5945']]
# Row 2: Average of last three values: 0.6121333333333333
#
# Row 3: [['0006', '0.6920'], ['0004', '0.6607'], ['0039', '0.6355']]
# Row 3: Average of last three values: 0.6627333333333333
#
# Row 4: [['0007', '0.6894'], ['0009', '0.6647'], ['0004', '0.6612']]
# Row 4: Average of last three values: 0.6717666666666666
#
# Row 5: [['0039', '0.5964'], ['0037', '0.5738'], ['0027', '0.5413']]
# Row 5: Average of last three values: 0.5705
#
# Row 6: [['0288', '0.5968'], ['0287', '0.5483'], ['0224', '0.5163']]
# Row 6: Average of last three values: 0.5538
#
# Row 7: [['0026', '0.5000'], ['0007', '0.4005'], ['0027', '0.3746']]
# Row 7: Average of last three values: 0.4250333333333334
#
# Row 8: [['0041', '0.4670'], ['0010', '0.4253'], ['0023', '0.4218']]
# Row 8: Average of last three values: 0.43803333333333333
#
# Row 9: [['0061', '0.6268'], ['0031', '0.6195'], ['0030', '0.5641']]
# Row 9: Average of last three values: 0.6034666666666667
#
# Row 10: [['0008', '0.5956'], ['0007', '0.5741'], ['0006', '0.4974']]
# Row 10: Average of last three values: 0.5557000000000001
#
# Row 11: [['0012', '0.5048'], ['0011', '0.4432'], ['0010', '0.4300']]
# Row 11: Average of last three values: 0.4593333333333333
#
# Row 12: [['0003', '0.6001'], ['0024', '0.5834'], ['0023', '0.5570']]
# Row 12: Average of last three values: 0.5801666666666666
#
# Row 13: [['0005', '0.7452'], ['0004', '0.7204'], ['0003', '0.7192']]
# Row 13: Average of last three values: 0.7282666666666667
#
# Row 14: [['0006', '0.7282'], ['0005', '0.6553'], ['0023', '0.5602']]
# Row 14: Average of last three values: 0.6479
#
# Row 15: [['0048', '0.8048'], ['0047', '0.7608'], ['0043', '0.6215']]
# Row 15: Average of last three values: 0.7290333333333333
#
# Row 16: [['0001', '0.7736'], ['0005', '0.7366'], ['0003', '0.7310']]
# Row 16: Average of last three values: 0.7470666666666667
#
# Row 17: [['0144', '0.5776'], ['0168', '0.5513'], ['0184', '0.5498']]
# Row 17: Average of last three values: 0.5595666666666667
#
# Row 18: [['0028', '0.4853'], ['0012', '0.4559'], ['0008', '0.3659']]
# Row 18: Average of last three values: 0.43570000000000003
#
# Row 19: [['0024', '0.7324'], ['0058', '0.7147'], ['0011', '0.6707']]
# Row 19: Average of last three values: 0.7059333333333333
#
# Row 20: [['0016', '0.7266'], ['66', '0.5524'], ['0015', '0.5209']]
# Row 20: Average of last three values: 0.5999666666666666
#
# Row 21: [['0008', '0.6168'], ['0009', '0.6141'], ['0012', '0.5476']]
# Row 21: Average of last three values: 0.5928333333333334
#
# Row 22: [['0018', '0.4510'], ['0009', '0.4455'], ['0030', '0.4264']]
# Row 22: Average of last three values: 0.44096666666666673
#
# Row 23: [['0016', '0.4490'], ['0014', '0.4415'], ['0019', '0.3833']]
# Row 23: Average of last three values: 0.42460000000000003
#
# Row 24: [['0055', '0.4528'], ['0027', '0.4247'], ['0056', '0.4236']]
# Row 24: Average of last three values: 0.4337
#
# Row 25: [['0013', '0.6194'], ['0012', '0.5881'], ['0006', '0.5655']]
# Row 25: Average of last three values: 0.5910000000000001
#
# Row 26: [['0003', '0.6058'], ['0004', '0.4239'], ['0007', '0.3193']]
# Row 26: Average of last three values: 0.44966666666666666
#
# Row 27: [['0559', '0.4477'], ['0003', '0.4076'], ['0005', '0.3912']]
# Row 27: Average of last three values: 0.4155
#
# Row 28: [['0069', '0.4648'], ['0075', '0.4372'], ['0073', '0.4080']]
# Row 28: Average of last three values: 0.4366666666666666
#
# Row 29: [['0058', '0.4582'], ['0081', '0.4560'], ['0082', '0.3720']]
# Row 29: Average of last three values: 0.42873333333333336
#
# Row 30: [['0001', '0.6955'], ['0005', '0.6314'], ['0003 ', '0.5285']]
# Row 30: Average of last three values: 0.6184666666666666
#
# Row 31: [['0006', '0.5348'], ['0003', '0.5150'], ['0039', '0.5048']]
# Row 31: Average of last three values: 0.5182000000000001
#
# Row 32: [['0003', '0.6031'], ['0002', '0.5952'], ['0028', '0.5795']]
# Row 32: Average of last three values: 0.5926
#
# Row 33: [['0003', '0.7047'], ['0002', '0.6931'], ['0010', '0.6803']]
# Row 33: Average of last three values: 0.6927
#
# Row 34: [['0001', '0.8801'], ['0002', '0.8025'], ['0007', '0.8007']]
# Row 34: Average of last three values: 0.8277666666666667
#
# Row 35: [['0006', '0.6517'], ['0176', '0.6263'], ['0169', '0.5591']]
# Row 35: Average of last three values: 0.6123666666666666
#
# Row 36: [['0002', '0.4038'], ['0014', '0.3011'], ['0003', '0.2995']]
# Row 36: Average of last three values: 0.3348
#
# Row 37: [['0004', '0.5086'], ['0007', '0.4920'], ['0003', '0.4753']]
# Row 37: Average of last three values: 0.49196666666666666
#
# Row 38: [['0009', '0.7676'], ['0003', '0.6031'], ['0023', '0.5327']]
# Row 38: Average of last three values: 0.6344666666666666
#
# Row 39: [['0014', '0.9340'], ['0004', '0.8582'], ['0001', '0.8300']]
# Row 39: Average of last three values: 0.8740666666666667
#
# Row 40: [['0005', '0.9584'], ['0009', '0.9025'], ['0001', '0.7270']]
# Row 40: Average of last three values: 0.8626333333333333
#
# Row 41: [['0004', '0.9458'], ['0001', '0.7070'], ['0002', '0.7062']]
# Row 41: Average of last three values: 0.7863333333333333
#
# Row 42: [['0004', '0.5272'], ['0005', '0.4987'], ['0042', '0.4216']]
# Row 42: Average of last three values: 0.4825
#
# Row 43: [['0001', '0.5628'], ['0003', '0.5310'], ['0044', '0.5289']]
# Row 43: Average of last three values: 0.5409
#
# Row 44: [['0046', '0.6494'], ['0044', '0.5736'], ['0003', '0.5457']]
# Row 44: Average of last three values: 0.5895666666666667
#
# Row 45: [['0009', '0.8029'], ['0008', '0.7891'], ['0004', '0.7668']]
# Row 45: Average of last three values: 0.7862666666666667
#
# Row 46: [['0169', '0.5866'], ['0162', '0.5835'], ['0005', '0.3969']]
# Row 46: Average of last three values: 0.5223333333333334
#
# Row 47: [['0006', '0.8410'], ['0004', '0.7972'], ['0005', '0.7898']]
# Row 47: Average of last three values: 0.8093333333333333
#
# Row 48: [['0005', '0.8268'], ['0032', '0.6712'], ['0007', '0.3466']]
# Row 48: Average of last three values: 0.6148666666666667
#
# Row 49: [['0002', '0.4843'], ['0096', '0.4656'], ['0004', '0.4272']]
# Row 49: Average of last three values: 0.45903333333333335

# %%
#Task 5 part 1.2
import pandas as pd

df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')
df['top123'] = df['PAparagraphs-sim-mpnet-top123'].apply(ast.literal_eval)
df['Average_similarity_of_sim-mpnet-top123'] = df['top123'].apply(lambda x: sum(float(item[1]) for item in x[-3:]) / 3)
df.to_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx', index=False)

# %%
#Task 5 part 1.3
import pandas as pd
df = pd.read_excel('gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx')

average_of_average_last_three = df['Average_similarity_of_sim-mpnet-top123'].mean()


print("Average of 'Average_similarity_of_sim-mpnet-top123' column:", average_of_average_last_three)
# Out:
# Average of 'Average_similarity_of_sim-mpnet-top123' column: 0.5849557823129252

# %%
#Task 6 Part 1 , PACited which are present in Json
import pandas as pd
import json

file_path = 'gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx'
df = pd.read_excel(file_path)

# Initialize variables to keep track of minimum, maximum, and total average scores
min_average_score = float('inf')
max_average_score = float('-inf')
total_average_score = 0.0
num_rows = 0

for index, row in df.iterrows():
    values = row['PAcited']
    values_list = [value.strip('[ ]') for value in values.split(',')]

    json_data = row['PAparagraphs_sim-mpnet']
    json_obj = json.loads(json_data)

    scores = [float(sentence['score']) for sentence in json_obj['sentences'] if sentence['id'] in values_list]

    average_score = sum(scores) / len(scores) if scores else 0.0

    # Update minimum and maximum average scores
    min_average_score = min(min_average_score, average_score)
    max_average_score = max(max_average_score, average_score)

    # Update total average score and increment the row counter
    total_average_score += average_score
    num_rows += 1

    print(f"Values: {','.join(values_list)}, Average Score: {average_score}")

# Calculate overall average score
overall_average_score = total_average_score / num_rows if num_rows > 0 else 0.0

# Print minimum, maximum, and overall average scores
print()
print(f"mpnet_min_simi_cited_paragraph: {min_average_score}")
print(f"mpnet_max_simi_cited_paragraph: {max_average_score}")
print(f"mpnet_avg_simi_cited_paragraph: {overall_average_score}")
# Out:
# Values: 0060,0061,0092, Average Score: 0.45999999999999996
# Values: 0005,0009,0015, Average Score: 0.5589333333333334
# Values: 0002,0006,0027, Average Score: 0.5992999999999999
# Values: 0005,0007,0019, Average Score: 0.6230333333333333
# Values: 0024,0025,0037, Average Score: 0.5038999999999999
# Values: 0228,0224,0290, Average Score: 0.43726666666666664
# Values: 0006,0029,0002, Average Score: 0.2282666666666667
# Values: 0008,0023,0041, Average Score: 0.3716333333333333
# Values: 0031,0034,0061, Average Score: 0.5816333333333333
# Values: 0002,0006,0030, Average Score: 0.45943333333333336
# Values: 0012,0037,0056, Average Score: 0.3596333333333333
# Values: 0003,0018,0025, Average Score: 0.4874
# Values: 0003,0017,0018, Average Score: 0.6087
# Values: 0005,0018,0023, Average Score: 0.5335
# Values: 0042,0043,0046, Average Score: 0.5455333333333333
# Values: 0001,0045,0009, Average Score: 0.6637
# Values: 0144,0172,0182, Average Score: 0.4768333333333333
# Values: 0010,0012,0028, Average Score: 0.43500000000000005
# Values: 0011,0024,0054, Average Score: 0.6349333333333333
# Values: 0016,0055,0066, Average Score: 0.5163
# Values: 0009,0012,0075, Average Score: 0.5455333333333333
# Values: 0001,0009,0030, Average Score: 0.4083333333333334
# Values: 0014,0017,0020, Average Score: 0.3584333333333333
# Values: 0027,0028,0053, Average Score: 0.37720000000000004
# Values: 0005,0012,0013, Average Score: 0.5812666666666667
# Values: 0058,0169,0001, Average Score: 0.2597
# Values: 0316,0677,0559, Average Score: 0.34236666666666665
# Values: 0068,0069,0072, Average Score: 0.3504
# Values: 0058,0072,0138, Average Score: 0.3792333333333333
# Values: 0014,0018,0013, Average Score: 0.4764333333333333
# Values: 0023,0038,0039, Average Score: 0.4529000000000001
# Values: 0018,0028,0024, Average Score: 0.5560666666666666
# Values: 0002,0003,0004, Average Score: 0.5676333333333333
# Values: 0001,0002,0003, Average Score: 0.8193999999999999
# Values: 0169,0176,0177, Average Score: 0.4806333333333333
# Values: 0014,0021,0027, Average Score: 0.26733333333333337
# Values: 0006,0025,0045, Average Score: 0.3489333333333334
# Values: 0009,0023,0165, Average Score: 0.5505
# Values: 0011,0014,0020, Average Score: 0.7628666666666666
# Values: 0002,0009,0020, Average Score: 0.6807
# Values: 0002,0004,0014, Average Score: 0.7162666666666667
# Values: 0004,0127,0042, Average Score: 0.4042333333333333
# Values: 0004,0044,0077, Average Score: 0.4065666666666667
# Values: 0020,0021,0043, Average Score: 0.4445666666666666
# Values: 0003,0006,0008, Average Score: 0.6072333333333333
# Values: 0108,0162,0169, Average Score: 0.4848666666666667
# Values: 0002,0006,0008, Average Score: 0.6616333333333334
# Values: 0004,0005,0032, Average Score: 0.6102
# Values: 0002,0096,0117, Average Score: 0.4402333333333333
#
# mpnet_min_simi_cited_paragraph: 0.2282666666666667
# mpnet_max_simi_cited_paragraph: 0.8193999999999999
# mpnet_avg_simi_cited_paragraph: 0.4985020408163265

# %%
#Task 6 Part 2 , PACited which are not present in Json

import pandas as pd
import json

file_path = 'gdrive/MyDrive/New-ClaimCiteRetrieval_ESR_based_24-02-2024.xlsx'
df = pd.read_excel(file_path)

# Initialize variables to keep track of minimum, maximum, and total average scores
min_average_score = float('inf')
max_average_score = float('-inf')
total_average_score = 0.0
num_rows = 0

for index, row in df.iterrows():
    values = row['PAcited']
    values_list = [value.strip('[ ]') for value in values.split(',')]

    json_data = row['PAparagraphs_sim-mpnet']
    json_obj = json.loads(json_data)

    scores = [float(sentence['score']) for sentence in json_obj['sentences'] if sentence['id'] not in values_list]

    average_score = sum(scores) / len(scores) if scores else 0.0

    # Update minimum and maximum average scores
    min_average_score = min(min_average_score, average_score)
    max_average_score = max(max_average_score, average_score)

    # Update total average score and increment the row counter
    total_average_score += average_score
    num_rows += 1

    print(f"Values: {','.join(values_list)}, Average Score: {average_score}")

# Calculate overall average score
overall_average_score = total_average_score / num_rows if num_rows > 0 else 0.0

# Print minimum, maximum, and overall average scores
print()
print(f"mpnet_min_simi_non-cited_paragraph: {min_average_score}")
print(f"mpnet_max_simi_non-cited_paragraph: {max_average_score}")
print(f"mpnet_avg_simi_non-cited_paragraph: {overall_average_score}")
# Out:
# Values: 0060,0061,0092, Average Score: 0.40598333333333336
# Values: 0005,0009,0015, Average Score: 0.46626666666666666
# Values: 0002,0006,0027, Average Score: 0.4809833333333333
# Values: 0005,0007,0019, Average Score: 0.5787666666666667
# Values: 0024,0025,0037, Average Score: 0.5074833333333334
# Values: 0228,0224,0290, Average Score: 0.4006166666666666
# Values: 0006,0029,0002, Average Score: 0.34325000000000006
# Values: 0008,0023,0041, Average Score: 0.3413
# Values: 0031,0034,0061, Average Score: 0.4296857142857142
# Values: 0002,0006,0030, Average Score: 0.43291666666666667
# Values: 0012,0037,0056, Average Score: 0.33149999999999996
# Values: 0003,0018,0025, Average Score: 0.47330000000000005
# Values: 0003,0017,0018, Average Score: 0.5675666666666668
# Values: 0005,0018,0023, Average Score: 0.5294500000000001
# Values: 0042,0043,0046, Average Score: 0.5040666666666667
# Values: 0001,0045,0009, Average Score: 0.60465
# Values: 0144,0172,0182, Average Score: 0.4955333333333333
# Values: 0010,0012,0028, Average Score: 0.28255
# Values: 0011,0024,0054, Average Score: 0.5337
# Values: 0016,0055,0066, Average Score: 0.3900142857142857
# Values: 0009,0012,0075, Average Score: 0.4622833333333333
# Values: 0001,0009,0030, Average Score: 0.29925
# Values: 0014,0017,0020, Average Score: 0.3334
# Values: 0027,0028,0053, Average Score: 0.38001666666666667
# Values: 0005,0012,0013, Average Score: 0.4512833333333333
# Values: 0058,0169,0001, Average Score: 0.36815
# Values: 0316,0677,0559, Average Score: 0.34425
# Values: 0068,0069,0072, Average Score: 0.3729
# Values: 0058,0072,0138, Average Score: 0.34165
# Values: 0014,0018,0013, Average Score: 0.5300166666666667
# Values: 0023,0038,0039, Average Score: 0.4577666666666667
# Values: 0018,0028,0024, Average Score: 0.5114833333333333
# Values: 0002,0003,0004, Average Score: 0.6590833333333332
# Values: 0001,0002,0003, Average Score: 0.6240333333333332
# Values: 0169,0176,0177, Average Score: 0.4645333333333333
# Values: 0014,0021,0027, Average Score: 0.27131666666666665
# Values: 0006,0025,0045, Average Score: 0.46175000000000005
# Values: 0009,0023,0165, Average Score: 0.41113333333333335
# Values: 0011,0014,0020, Average Score: 0.7124666666666667
# Values: 0002,0009,0020, Average Score: 0.6747166666666667
# Values: 0002,0004,0014, Average Score: 0.5815833333333335
# Values: 0004,0127,0042, Average Score: 0.36345
# Values: 0004,0044,0077, Average Score: 0.4068333333333333
# Values: 0020,0021,0043, Average Score: 0.5462333333333333
# Values: 0003,0006,0008, Average Score: 0.6839666666666666
# Values: 0108,0162,0169, Average Score: 0.30038333333333334
# Values: 0002,0006,0008, Average Score: 0.63225
# Values: 0004,0005,0032, Average Score: 0.2750166666666667
# Values: 0002,0096,0117, Average Score: 0.37843333333333334
#
# mpnet_min_simi_non-cited_paragraph: 0.27131666666666665
# mpnet_max_simi_non-cited_paragraph: 0.7124666666666667
# mpnet_avg_simi_non-cited_paragraph: 0.4571268707482993
